# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Raw data plotter

# %%
mat = scipy.io.loadmat('Raw_Data/3_Phase_To_Ground/350/1/0001.mat')
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'sim_version', 'sim_date', 'x', 'Iprobe1_a', 'Iprobe1_b', 'Iprobe1_c', 'Iprobe2_a', 'Iprobe2_b', 'Iprobe2_c', 'x1', 'hmod_Iprobe1_a_1_60', 'hpha_Iprobe1_a_1_60', 'hmod_Iprobe2_a_1_60', 'hpha_Iprobe2_a_1_60', 'PhaseAngle_a', 'hmod_Iprobe1_b_1_60', 'hpha_Iprobe1_b_1_60', 'hmod_Iprobe2_b_1_60', 'hpha_Iprobe2_b_1_60', 'PhaseAngle_b', 'PhaseAngle_c', 'SM1_Pe', 'SM2_Pe', 'SM3_Pe', 'SM4_Pe', 'sim_name_y', 'sim_desc_y', 'sim_unit_y', 'sim_name_x', 'sim_unit_x'])

# %%
plt.plot(mat['Iprobe2_a'])
plt.plot(mat['Iprobe2_b'])
plt.plot(mat['Iprobe2_c'])

# %%
plt.plot(mat['PhaseAngle_a'][0:1000])
plt.plot(mat['PhaseAngle_b'][0:1000])
plt.plot(mat['PhaseAngle_c'][0:1000])

# %%
# Out:
# [-179.776214]
# [179.59796899]
# [179.78935253]
