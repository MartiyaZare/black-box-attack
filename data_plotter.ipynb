# %%
#import scipy.io
#import matplotlib.pyplot as plt
import numpy as np
from MZPackage.Utilities import *
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### PLAYGROUND

# %%
#TMP IMPORTS ARE ALL INCLUDED IN TOP CELL
import numpy as np
from MZPackage.Utilities import *
import matplotlib.pyplot as plt
import numpy as np

PlotRawDataDat(path = "Raw_Data\YM\diff_nofault\data\diff_nofault-1\HypProc_1",fileIndex = 1, featureIndexes = [x for x in range(4,5)])

# %%
PlotRawDataDat(path = "Raw_Data\YM\diff\diff_0\data\diff_0-1\HypProc_1",fileIndex = 1, featureIndexes = [x for x in range(1,2)])

# %%
dataSet = loadData("Anomaly_Detection_Model_Data/normalized_data_set")
plotOneSequenceFromData(dataSet,0,2)

# %%
plt.plot(dataSet[0,:,0:3])

# %%
dataSet = loadData("attacks_generated_cnn")
plt.plot(dataSet[6,:,0:3])

# %%
dataSet = loadData("Anomaly_Detection_Model_Data/normalized_replay_attack_data_set")
plt.plot(dataSet[8,:,0:3])

# %%
# PLOT sample code

import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"
names = [1, 5, 10, 100]
values = [1, 10, 100, 2]
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.xticks(np.arange(0, 101, step=5))
#plt.ylim(-2, 2)
plt.plot(names, values)
plt.show()

plt.savefig('file_name.eps', format='eps', dpi=600, bbox_inches='tight')
