# %%
import numpy as np

from MZPackage.DataPreprocessor import DataPreprocessor
from MZPackage.ModelBuilder import ModelBuilder
from MZPackage.Utilities import *

# %%
dp = DataPreprocessor()
mb = ModelBuilder()

# %% [markdown]
# ### Prepare attack data

# %%
# testSet, testSetLabels = dp.getAttackData(dataSetfolderParam="Anomaly_Detection_Model_Data") # Uncomment to generate new data
# testSet, testSetLabels = dp.getOldAttackData()
# Out:
# Anomaly_Detection_Model_Data/normalized_data_set

# %%
# setThreParam = 1
# advParam = 0
# # To store thresholds
# thresholds = {}

# %% [markdown]
# ### 1D Conv

# %%
# modelType = "conv"
# precision, recall, precisionThre, recallThre, thre, minPositiveMSE, maxNegativeMSE = mb.testModel(testSet, testSetLabels, modelType, setThre = setThreParam, adv = advParam)
# thresholds[modelType] = thre
# saveData(thresholds,"Anomaly_Detection_Model_Data/thresholds")
# Out:
# Precision without threshold is:  1.0
# Recall without threshold is:  1.0
# Min reconstruction error for anomalies:  6.366663237691077e-05
# max reconstruction error for benign:  5.9986222612125515e-05
# Selected threshold:  6.035426358860404e-05
# Precision by threshold is:  1.0
# Recall by threshold is:  1.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-3cdaa7d101ef> in <module>
#       1 modelType = "conv"
# ----> 2 precision, recall, precisionThre, recallThre, thre, minPositiveMSE, maxNegativeMSE = mb.testModel(testSet, testSetLabels, modelType, setThre = setThreParam, adv = advParam)
#       3 thresholds[modelType] = thre
#       4 saveData(thresholds,"Anomaly_Detection_Model_Data/thresholds")
#
# ValueError: too many values to unpack (expected 7)

# %% [markdown]
# ### Attack samples test

# %%
generatedSamples = loadData("Second_Test_System_Fault_Generator/attacks_generated_cnn")

# %%
generatedSamples.shape
# Out:
# (1000, 48, 6)

# %%
testInput = generatedSamples
testLabels = np.asarray([1] * generatedSamples.shape[0])
modelType = "conv"
advParam = 0
_, _, _, _, _, minPositiveMSE, _, mse = mb.testModel(testInput, testLabels, modelType, setThre = 0, adv = advParam, thresholdFolderParam="Anomaly_Detection_Model_Data", vrbs=0)

# %%
thres = loadData("Anomaly_Detection_Model_Data/thresholds")
thre = thres["conv"]
sum(mse < thre) / 1000
# Out:
# 0.0

# %%
mse
# Out:
# array([0.00218509, 0.00512771, 0.00539854, 0.00743663, 0.01202957,
#        0.0066992 , 0.00237603, 0.01071799, 0.01666394, 0.00915853,
#        0.00197814, 0.00218509, 0.00447019, 0.00318948, 0.00433335,
#        0.01273129, 0.00205268, 0.0120101 , 0.01545673, 0.01666394,
#        0.00184549, 0.003757  , 0.00174112, 0.0099055 , 0.00325143,
#        0.00659954, 0.0077607 , 0.01021137, 0.00568345, 0.00595645,
#        0.00263611, 0.00207731, 0.00235722, 0.01426364, 0.00320586,
#        0.00786259, 0.00681631, 0.00218453, 0.00216763, 0.01141285,
#        0.0129968 , 0.01361433, 0.0075903 , 0.00198961, 0.00789709,
#        0.00777116, 0.01046567, 0.01647674, 0.00239742, 0.01442764,
#        0.01608958, 0.00278589, 0.01541869, 0.01665875, 0.01081004,
#        0.01661321, 0.00932323, 0.00184171, 0.01175426, 0.01614412,
#        0.00325176, 0.00209332, 0.00743663, 0.00201302, 0.00253963,
#        0.01311323, 0.01614412, 0.00311738, 0.00217378, 0.00177682,
# ...

# %%
MSEs
# Out:
# [1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
#  1.57259953006509e-05,
# ...

# %% [markdown]
# # GAN test

# %%
ganSamples = loadData("dataset_generated_gan")
testInput = ganSamples
testLabels = np.asarray([1] * ganSamples.shape[0])
modelType = "conv"
advParam = 0
_, _, _, _, _, minPositiveMSE, _, mse = mb.testModel(testInput, testLabels, modelType, setThre = 0, adv = advParam, thresholdFolderParam="Anomaly_Detection_Model_Data", vrbs=1)
thres = loadData("Anomaly_Detection_Model_Data/thresholds")
thre = thres["conv"]
print("performance", sum(mse < thre) / 1000)
print("mean of MSE for attack samples", np.mean(mse))
# Out:
# Precision without threshold is:  1.0
# Recall without threshold is:  1.0
# Min reconstruction error for anomalies:  0.0007036055321805179
# max reconstruction error for benign:  nan
# Selected threshold:  5.683724954407245e-05
# Precision by threshold is:  1.0
# Recall by threshold is:  1.0
# performance 0.0
# mean of MSE for attack samples 0.0013553597

# %% [markdown]
# ### Attack Samples Test on CNN trained on GAN data

# %%
generatedSamples = loadData("attacks_generated_cnn_using_GAN_data")

# %%
generatedSamples.shape
# Out:
# (1000, 48, 6)

# %%
testInput = generatedSamples
testLabels = np.asarray([1] * generatedSamples.shape[0])
modelType = "conv"
advParam = 0
_, _, _, _, _, minPositiveMSE, _, mse = mb.testModel(testInput, testLabels, modelType, setThre = 0, adv = advParam, thresholdFolderParam="Anomaly_Detection_Model_Data", vrbs=0)

# %%
thres = loadData("Anomaly_Detection_Model_Data/thresholds")
thre = thres["conv"]
sum(mse < thre + 0.00005) / 1000
# Out:
# 0.318

# %%
mse
# Out:
# array([1.33009262e-04, 1.27156801e-04, 4.69358554e-04, 1.25356446e-04,
#        7.50987231e-05, 7.14513781e-05, 1.25783097e-04, 1.06243412e-04,
#        3.38091347e-04, 7.49694881e-05, 1.16299868e-04, 2.86132872e-04,
#        1.25069012e-04, 1.92113480e-04, 4.65486632e-04, 1.38617636e-04,
#        7.73903816e-05, 1.19340319e-04, 1.47848694e-04, 1.38777627e-04,
#        3.78717347e-04, 1.42717605e-04, 3.80928819e-04, 1.00634463e-04,
#        1.34295901e-04, 1.39606816e-04, 8.32832186e-05, 9.73465854e-05,
#        3.27614710e-04, 9.59831716e-05, 1.40940877e-04, 1.37854963e-04,
#        1.42891444e-04, 1.59760138e-04, 4.09916953e-04, 1.34567816e-04,
#        7.20361864e-05, 8.96320576e-05, 1.24968747e-04, 1.43610594e-04,
#        1.10248425e-04, 1.63696129e-04, 4.92419061e-04, 1.16689583e-04,
#        1.89581041e-04, 7.49237442e-05, 8.06860082e-05, 7.79659067e-05,
#        9.73636945e-05, 2.89584068e-04, 7.50987231e-05, 7.06805527e-05,
# ...
